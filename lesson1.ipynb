# %%
"""Урок по гит."""
# Out:
# Для выполнения ячеек с "base (Python 3.13.12)" требуется пакет ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Создать среду Python</a> с необходимыми пакетами.
#
# Или установите "ipykernel" с помощью следующей команды: "conda install -n base ipykernel --update-deps --force-reinstall"

# %%
1 + 1
# Out:
# 2
